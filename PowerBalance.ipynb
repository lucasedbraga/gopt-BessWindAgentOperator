# %%
from plots.PlotPowerBalance import BarraPowerPlotter

# %%
# Exemplo de uso
plotter = BarraPowerPlotter(db_path='../DATA/output/RNA_DATA_ACOPF.db')  # Usará o primeiro cenário encontrado
# Para um cenário específico: plotter = BarraPowerPlotter(cen_id='20250213143000')
plotter.plot_all_barras(save_fig=False)
# plotter.plot_resumo_global(save_fig=False)
# Out:
# ℹ️  Nenhum cen_id informado. Usando o primeiro disponível: 20260530193031_00000
# 📊 Carregando dados da tabela DBAR_results para o cenário 20260530193031_00000...
# ✅ Dados carregados: 2832 registros, 118 barras.
#    Barras com bateria: []
