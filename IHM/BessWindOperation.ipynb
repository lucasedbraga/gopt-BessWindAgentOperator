# %%
from PlotBessWindOperation import BatteryPlotter

# %%
plotter = BatteryPlotter(db_path='../DATA/output/resultados_PL.db',cen_id='20260222171104')
plotter.plot_all_batteries()
# Out:
# ⚠️  Bateria na barra 2 não teve operação (todos os valores de potência ≈ 0).
# ⚠️  Bateria na barra 3 não teve operação (todos os valores de potência ≈ 0).
# ⚠️  Bateria na barra 4 não teve operação (todos os valores de potência ≈ 0).
# ⚠️  Bateria na barra 6 não teve operação (todos os valores de potência ≈ 0).
