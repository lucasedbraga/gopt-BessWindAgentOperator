# %%
from PlotPowerBalance import PowerBalancePlotter

# %%
plotter = PowerBalancePlotter(db_path='../DATA/output/resultados_PL.db')
plotter.plot_operation_panel()
# Out:
# ℹ️  Nenhum cen_id informado. Usando o primeiro disponível: 20260213163935
# 📊 Carregando dados para o cenário 20260213163935...
# ✅ Dados carregados: 48 horas, 4 tipos de geradores, 48 registros de bateria.
