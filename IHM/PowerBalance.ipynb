# %%
from plots.PlotPowerBalance import BarraPowerPlotter

# %%
# Exemplo de uso
plotter = BarraPowerPlotter(db_path='../DATA/output/resultados_PL.db')  # Usará o primeiro cenário encontrado
# Para um cenário específico: plotter = BarraPowerPlotter(cen_id='20250213143000')
plotter.plot_all_barras(save_fig=False)
# plotter.plot_resumo_global(save_fig=False)
# Out:
# ℹ️  Nenhum cen_id informado. Usando o primeiro disponível: 20260227085246
# 📊 Carregando dados da tabela DBAR_results para o cenário 20260227085246...
# ✅ Dados carregados: 72 registros, 3 barras.
#    Barras com bateria: [2]
