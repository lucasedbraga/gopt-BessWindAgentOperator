# %%
from plots.PlotLines import PlotLine

# %%
plotter = PlotLine(db_path= '../DATA/output_CUR_oficial/resultados_PL_acoplado.db')  # Usa o primeiro cenário
plotter.plot_all_hours(save_fig=False, show_edge_values=False, figsize=(20,15))
# Out:
#   Nenhum cen_id informado. Usando o primeiro disponível: 20260330010648
#   Usando primeiro instante disponível: data=1, hora=00
#  Carregando dados das linhas para cenário 20260330010648, data 1, hora 00...
#  Dados carregados: 186 linhas.
#  Gerando gráficos para 24 instantes...
#
# [1/24] Processando data 1, hora 00...
#  Carregando dados das linhas para cenário 20260330010648, data 1, hora 00...
#  Dados carregados: 186 linhas.
# [2/24] Processando data 1, hora 01...
#  Carregando dados das linhas para cenário 20260330010648, data 1, hora 01...
#  Dados carregados: 186 linhas.
# [3/24] Processando data 1, hora 02...
#  Carregando dados das linhas para cenário 20260330010648, data 1, hora 02...
#  Dados carregados: 186 linhas.
# [4/24] Processando data 1, hora 03...
#  Carregando dados das linhas para cenário 20260330010648, data 1, hora 03...
#  Dados carregados: 186 linhas.
# [5/24] Processando data 1, hora 04...
# ...
