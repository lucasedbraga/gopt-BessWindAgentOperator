# %%
from plots.PlotLines import PlotLine

# %%
plotter = PlotLine(db_path= '../DATA/output/resultados_PL.db')  # Usa o primeiro cenário
plotter.plot_all_hours(save_fig=False)
# Out:
#   Nenhum cen_id informado. Usando o primeiro disponível: 20260225193349
#   Usando primeiro instante disponível: data=1, hora=00
#  Carregando dados das linhas para cenário 20260225193349, data 1, hora 00...
#  Dados carregados: 20 linhas.
#  Gerando gráficos para 24 instantes...
#
# [1/24] Processando data 1, hora 00...
#  Carregando dados das linhas para cenário 20260225193349, data 1, hora 00...
#  Dados carregados: 20 linhas.
# [2/24] Processando data 1, hora 01...
#  Carregando dados das linhas para cenário 20260225193349, data 1, hora 01...
#  Dados carregados: 20 linhas.
# [3/24] Processando data 1, hora 02...
#  Carregando dados das linhas para cenário 20260225193349, data 1, hora 02...
#  Dados carregados: 20 linhas.
# [4/24] Processando data 1, hora 03...
#  Carregando dados das linhas para cenário 20260225193349, data 1, hora 03...
#  Dados carregados: 20 linhas.
# [5/24] Processando data 1, hora 04...
# ...
